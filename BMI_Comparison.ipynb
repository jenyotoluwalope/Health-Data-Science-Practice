# %%
patient_name = "Musa"
age = 25
weight_kg = 95
height_m = 1.75
print(patient_name)
print(weight_kg)
bmi = weight_kg / (height_m * height_m)
print("The BMI is:")
print(bmi)
if bmi < 25:
  print("Diagnosis: Healthy Weight")
else:
    print("Diagnosis: Overweight")
weights = [70, 85, 95, 60, 102]
names = {"Musa", "Chioma", "Ibrahim", "Ngozi", "david"}
print(weights)
for w in weights:
  bmi = w / (1.75 * 1.75)
  print("Patient BMI:", bmi)
for w in weights:
  bmi = w / (1.75 * 1.75)
  if bmi > 25:
    print(w, "kg is Overweight")
  else:
    print(w, "kg is Healthy")
import pandas as pd
data = {
    'Patient_Name': ["Musa", "Chioma", "Ibrahim", "Ngozi", "David"],
    'Weight_kg': [70, 85, 95, 60, 102],
    'Height_m': [1.75, 1.60, 1.80, 1.65, 1.75]
}
df = pd.read_json(pd.DataFrame(data).to_json())
df = pd.DataFrame(data)
df
df['BMI'] = df['Weight_kg'] / (df['Height_m'] ** 2)
df
overweight_patients = df[df['BMI'] > 25]
overweight_patients
import matplotlib.pyplot as plt
plt.bar(df['Patient_Name'], df['BMI'], color='skyblue')
plt.title("Patient BMI Comparison")
plt.xlabel("Patient Name")
plt.ylabel("BMI Score")
plt.axhline(y=25, color='red', linestyle='--')
plt.show()
# Out:
# Musa
# 95
# The BMI is:
# 31.020408163265305
# Diagnosis: Overweight
# [70, 85, 95, 60, 102]
# Patient BMI: 22.857142857142858
# Patient BMI: 27.755102040816325
# Patient BMI: 31.020408163265305
# Patient BMI: 19.591836734693878
# Patient BMI: 33.30612244897959
# 70 kg is Healthy
# 85 kg is Overweight
# 95 kg is Overweight
# 60 kg is Healthy
# 102 kg is Overweight
# /tmp/ipython-input-3118483191.py:32: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(pd.DataFrame(data).to_json())
